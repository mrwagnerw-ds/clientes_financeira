# %%
# Introdução

"""
O cientista de dados irá implementar os projetos.

Quando tratamos de Gestão de Projetos, existem dois paradigmas:
Clássico(Waterfall) e Ágil

Clássico:
* Grande esforço em planejar e estimar todo o projeto no início.
* Conhecimento de custos, cronogramas e escopos.
* Procura-se manter o plano durante o desenvolvimento.

Ágeis:
* Time box, que são intervalos menores de tempo.
* Podendo mudar a cada time box.

"""

# %%
# Conceitos Gerais.

"""
O que é um projeto?
É um esforço temporário empreendido para criar um produto, serviço ou resultado exclusivo.

Por que nós precisamos do gerenciamento de projetos?
* 26% dos projetos têm sucesso.
* 46% dos projetos têm alterações.
* 28% dos projetos falham. 
* Média de 89% terminam acima do curso.
* Média de 122% atrasado no cronograma.
* 45% das funcionalidades não são utilizadas.

"""

# %%
# Modelo Clássico.

"""
Ciclo de vida.
* Requerimentos
* Análises
* Design
* Implementação.
* Testes

"""

# %%
# PMO.

"""
Project Manager Office.

É uma estrutura dentro da empresa que coordena os projetos.

"É uma das formas de aumentar a maturidade em gerenciamento de projetos nos tempos atuais, tem sido a formalização da implantação
de escritório de projetos nas organizações." 

Tipos de escritórios:
* Suporte.
* Controle.
* Diretivo.

"""

# %%
# Mentalidade e Princípios Ágeis.

"""
Oposição ao método cascata.
Adaptativo.
Curto períodos.
Comunicação em tempo real.
Produção de menos documentação.
Equipe horizontal.
Consenso da equipe em vez de autoridade.


Indíviduos e interações > Processos e ferramentas.
Software em funcionamento > Documentação abrangente.
Colaboração com o cliente > Negociação de contratos.
Responder a mudanças > Seguir um plano.

"""

# %%
# 12 Princípios Ágeis.

"""
1 - Satisfação do cliente com bom software.
2 - Mudanças são bem vindas.
3 - Entregas frequentes.
4 - Trabalhe com pessoas de negócios. 
5 - Motive as pessoas.
6 - Conversa face a face.
7 - Meça sofware pronto.
8 - Mantenha um ritmo constante.
9 - Mantenha excelência técnica e design. 
10 - Mantenha o código simples.
11 - Equipes criam melhores arquiteturas.
12 - Refletir e ajustar.

"""

# %%
# Metodologias Ágeis.

"""
Scrum
XP (Extreme Programming)
FDD (Feature Driven Development)
DSMD (Dynamic Systems Devepment Method)
Crystal
Lean
Kanban


Scrum:
Transparência.
Inspeção.
Adaptação.

Kanban:
Quadro indicador.
Define o andamento.
Limite do trabalho em progresso.

"""

# %%
# Conclusão.

"""
Ágeis:
Pequenos projetos, no máximo 20 desenvolvedores.
Apoio da organização.
Comunicação facilitada.
Baixa criticidade.
Mudanças frequentes.

Não recomendado:
Grando número de desenvolvedores.
Equipes alocadas em diferentes lugares (obsoleto).
Alta criticidade.
Cultura organizacional.
Questões legais.















"""
