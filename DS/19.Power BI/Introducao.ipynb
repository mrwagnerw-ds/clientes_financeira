# %%
"""
* Conhecer os fundamentos do Power BI.
* Colocar em prática os conceitos de boas práticas.
* Se familiarizar com as ferramentas de dashboards.


Power BI é uma plataforma de visualização de dados.
Plataforma de Business Intelligence.

"""
# Out:
# '\n* Conhecer os fundamentos do Power BI.\n* Colocar em prática os conceitos de boas práticas.\n* Se familiarizar com as ferramentas de dashboards.\n\n\nPower BI é uma plataforma de visualização de dados.\nPlataforma de Business Intelligence.\n\n'

# %%
"""
Principais ferramentas:

* Desktop - Para criar relatórios e conexões.
* Service - Serviços online onde os relatórios são publicados.
* Gateway - Conexão com fontes de dados.
* Mobile Apps - Visualização para celulares.

"""
