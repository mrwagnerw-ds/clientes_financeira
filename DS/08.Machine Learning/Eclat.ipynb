# %%
import pandas as pd
from pyECLAT import ECLAT

# %%
base = pd.read_csv('C:/Users/mrwag/OneDrive/Big Data/DS/21.Textos/transacoes.txt', header = None)
base
# Out:
#          0        1        2
# 0  Cerveja    Pizza  Sorvete
# 1    Pizza  Sorvete      NaN
# 2  Cerveja    Pizza      NaN
# 3  Cerveja    Pizza  Sorvete
# 4  Cerveja    Pizza      NaN
# 5    Pizza      NaN      NaN

# %%
# Instanciando o ECLAT com o banco de dados.

resumo = ECLAT(data = base, verbose = True)
suporte = resumo.fit(min_support = 0.1, min_combination = 1, max_combination = 4)
suporte
# Out:
# ...
# 100%|██████████| 3/3 [00:00<00:00, 974.06it/s]
# Combination 1 by 1
# 3it [00:00, 342.90it/s]
# Combination 2 by 2
# 3it [00:00, 225.33it/s]
# Combination 3 by 3
# 1it [00:00, 110.05it/s]
# Combination 4 by 4
# 0it [00:00, ?it/s]
# ({'Pizza': [0, 1, 2, 3, 4, 5],
#   'Cerveja': [0, 2, 3, 4],
#   'Sorvete': [0, 1, 3],
#   'Pizza & Cerveja': [0, 2, 3, 4],
#   'Pizza & Sorvete': [0, 1, 3],
#   'Cerveja & Sorvete': [0, 3],
#   'Pizza & Cerveja & Sorvete': [0, 3]},
#  {'Pizza': 1.0,
#   'Cerveja': 0.6666666666666666,
#   'Sorvete': 0.5,
#   'Pizza & Cerveja': 0.6666666666666666,
#   'Pizza & Sorvete': 0.5,
#   'Cerveja & Sorvete': 0.3333333333333333,
#   'Pizza & Cerveja & Sorvete': 0.3333333333333333})
