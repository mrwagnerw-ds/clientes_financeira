# %%
# Introdução.

"""
A preferência para colocar os dados na nuvem, para a empresa, é para não centralizar em algum lugar seu banco de dados.

Quem cuida disso?
Departamento de TI.
Empresa Terceirizada.

O que pode ser contratado?
Processamento.
Armazenamento.
Bando de dados.
Inteligência Artificial.
IOT = Internet Of Things (Internet das Coisas)

De quem contratar?
AWS - Amazon.
Azure - Microsoft.
GCP - Google


"""

# %%
# O que pode ser contratado?

"""
Uma aplicação completa.
Computação:
    Servidores virtuais.
    Processamento em Lotes.
    Containers.

Banco de Dados:
    Relacional.
    NoSql.
    Em Cache.
    Oracle/MongoDB/SQL Server.

Desevolvimento de Software:
    IDES.
    Depuradores.
    Teste.
    Gestão de Pipeline.
    Repositórios/Controle de Versão.


"""

# %%
# Tipos de Serviços.

"""
Nuvem Pública.
Nuvem Privada.
Nuvem Hibrida.
HPC - High Performance Computer

"""

# %%
# Provedores.

"""
AWS.
Azure.
GCP.

São os líderes em provedores de serviços e ferramentas na nuvem. 

"""

# %%
# AWS.

"""
Precisa criar uma conta.




"""
