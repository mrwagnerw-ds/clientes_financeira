# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Carregamento da base de dados.
# posso adicionar a letra 'r' no começo do caminho para indicar leitura do arquivo.

base = pd.read_csv('C:/Users/mrwag/OneDrive/Big Data/DS/21.Textos/trees.csv') 
base.shape
# Out:
# (31, 3)

# %%
base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
# Criação do Histograma, considerando somente o segundo atributo da base de dados e suas divisões.

h = np.histogram(base.iloc[:,1], bins=6)
h
# Out:
# (array([4, 2, 5, 7, 9, 4]), array([63., 67., 71., 75., 79., 83., 87.]))

# %%
# Visualização do histograma com 6 divisões/barras (bins).

plt.hist(base.iloc[:,1], bins = 8)
plt.title('Árvores')
plt.ylabel('Frequência')
plt.xlabel('Altura')
# Out:
# Text(0.5, 0, 'Altura')
