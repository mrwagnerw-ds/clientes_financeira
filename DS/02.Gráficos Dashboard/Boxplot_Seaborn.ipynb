# %%
import pandas as pd
import seaborn as sbn

# %%
# Base de dados.

base = pd.read_csv('C:/Users/mrwag/OneDrive/Big Data/DS/21.Textos/trees.csv')
base.shape
# Out:
# (31, 3)

# %%
# Visualizando o boxplot.

sbn.boxplot(data = base.Volume, orient = 'v').set_title('Árvores')
# Out:
# Text(0.5, 1.0, 'Árvores')

# %%
# Vários boxplots na mesma imagem

sbn.boxenplot(data = base)
# Out:
# <Axes: >

# %%
sbn.boxplot(data = base)
# Out:
# <Axes: >
