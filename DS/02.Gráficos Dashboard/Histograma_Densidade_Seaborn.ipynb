# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

# %%
base = pd.read_csv('C:/Users/mrwag/OneDrive/Big Data/DS/21.Textos/trees.csv')
base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
# Histograma com 10 bins(barras) e com gráfico de densidade.
#stat = count, density, probability, percent, frequency

sbn.histplot(base.Volume, color = 'blue', kde = True, stat = 'density', bins = 10).set(title = 'Volume')
# Out:
# [Text(0.5, 1.0, 'Volume')]

# %%
# Outra base de dados.

base2 = pd.read_csv('C:/Users/mrwag/OneDrive/Big Data/DS/21.Textos/chicken.csv')
base2.shape
# Out:
# (71, 2)

# %%
# Criando novo dataframe com o atributo 'feed'.

grupo = base2.groupby(['feed'])['weight'].sum()
grupo
# Out:
# feed
# casein       3883
# horsebean    1602
# linseed      2625
# meatmeal     3046
# soybean      3450
# sunflower    3947
# Name: weight, dtype: int64

# %%
# Novo dataframe para testar os filtros do panda.

teste = base2.loc[base2['feed'] == 'horsebean']
teste
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean
# 5     168  horsebean
# 6     108  horsebean
# 7     124  horsebean
# 8     143  horsebean
# 9     140  horsebean

# %%
# Historgama somente com 'horsebean'.

sbn.kdeplot(base2.loc[base2['feed'] == 'horsebean'].weight).set(title = 'Horsebean')
# Out:
# [Text(0.5, 1.0, 'Horsebean')]

# %%
sbn.histplot(base2.loc[base2['feed']== 'casein'].weight, kde = True).set(title = 'Casein')
# Out:
# [Text(0.5, 1.0, 'Casein')]

# %%
# Gráfico 2 x 3 ( 3 linhas e 2 colunas).

plt.figure(layout = 'tight')
plt.subplot(3,2,1)
sbn.histplot(base2.loc[base2['feed']== 'horsebean'].weight, kde = True).set(title = 'Horsebean')
plt.subplot(3,2,2)
sbn.histplot(base2.loc[base2['feed']== 'casein'].weight, kde = True).set(title = 'Casein')
plt.subplot(3,2,3)
sbn.histplot(base2.loc[base2['feed']== 'linseed'].weight, kde = True).set(title = 'Linseed')
plt.subplot(3,2,4)
sbn.histplot(base2.loc[base2['feed']== 'meatmeal'].weight, kde = True).set(title = 'Meatmeal')
plt.subplot(3,2,5)
sbn.histplot(base2.loc[base2['feed']== 'soybean'].weight, kde = True).set(title = 'Soybean')
plt.subplot(3,2,6)
sbn.histplot(base2.loc[base2['feed']== 'sunflower'].weight, kde = True).set(title = 'Sunflower')
# Ajuste para tirar sobreposição.
#plt.tight_layout()
# Out:
# [Text(0.5, 1.0, 'Sunflower')]
