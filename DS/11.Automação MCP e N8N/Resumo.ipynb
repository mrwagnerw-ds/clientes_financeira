# %%
# MCP = Model Context Protocol.

"""
Formato de dados Padronizados para Interação com LLMs.

O MCP Server consulta os dados no MCP Client.


Vantagens:
* Comunicação padronizada entre clientes e servidores.
* Abstração entre servidores e recursos externos.
* Independência do modelo LLM.
* Reuso de ferramentas.
* Escalabilidade e modularidade.
* Segurança e controle.
* Melhor depuração.
* Facilidade de integração com frameworks de agentes.

"""

# %%
# Low-Code e No-Code

"""
São técnicas e ferramentas para criar aplicações com pouco ou nenhum código.
Usada para automações tanto para Frontend e Backend e Big Data.

*Bubble
*N8n
*Zapier

"""
