# %%
# Spark 

"""
Componentes:

Machine Learning (MLlib).
SQL (Spark SQL).
Processamento em Streaming.
Processamento em Grafos (Graphx).

Transformações e Ações:

* Um dataframe é imutável: traz tolerância a falhas.
* Uma transformação gera um novo dataframe.
* O processo de transformação só ocorre de fato com uma Ação: Lazy Evaluation


Lazy Evaluation:

Filter = Transformação.
Union = Transformação.
Sample = Transformação.
Show = Ação.


Como utilizar o Spark?

* Instalar a versão Open Source.
https://spark.apache.org/

Utilizar um provedor na nuvem.
AWS
Azure
Databricks
    

"""
