# %%
# Apache Spark

"""
Armazenamento.
Processamento.

Processamento:
Produzir valor aos dados.
Poder computacional.


Spark:
* Ferramenta de processamento de dados distribuídos em um cluster (rede de computadores).
* Veloz
* Escalável
* Em memória
* Particionamento

Replicação:
Dados são copiados entre os nós do cluster. Isso traz o benefício de, entre outras coisas, tolerância a falhas.

Partionamento:
Seria dividir dados em diferentes nós.


Spark / Python / R / Banco de Dados

Processamento de dados.
Custo Computacional
Spark tem arquitetura voltada a processar dados:
* Melhor performance.
* Não substitui Python
* Não substitui SQL.


Por que Sparks?

Pela alta perfomance e pela natureza particionada.

E o Pyspark.
O melhor dos dois mundos, tudo do python e tudo do sparks.


"""
