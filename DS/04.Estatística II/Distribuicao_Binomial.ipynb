# %%
from scipy.stats import binom

# %%
# Jogar uma moeda 5 vezes, qual a probabilidade de dar cara 3 vezes?
# (Eventos, Experimentos, Probabilidade)

prob = binom.pmf(3, 5, 0.5)
prob
# Out:
# np.float64(0.3124999999999998)

# %%
# Passar em 4 semáforos de 4 tempos, qual a probabilidade de pegar sinal verde
# nenhuma, 1 , 2, 3, 4 vezes seguidas!

binom.pmf(0,4,0.25) + binom.pmf(1, 4, 0.25) + binom.pmf(2, 4, 0.25) + binom.pmf(3, 4, 0.25) + binom.pmf(4, 4, 0.25)
# Out:
# np.float64(1.0000000000000002)

# %%
# E se forem sinais de 2 tempos?

binom.pmf(4, 4, 0.5)
# Out:
# np.float64(0.0625)

# %%
# Probabilidade cumulativa.

binom.cdf(4, 4, 0.25)
# Out:
# np.float64(1.0)

# %%
# Num concurso com 12 questões, qual a probabilidade de acertar 7 questões, considerando que cada questão tem 4 alternativas!

binom.pmf(7, 12, 0.25) * 100
# Out:
# np.float64(1.1471271514892587)

# %%
# Probabilidade de acertar as 12?

binom.pmf(12,12,0.25) * 100
# Out:
# np.float64(5.9604644775390625e-06)
