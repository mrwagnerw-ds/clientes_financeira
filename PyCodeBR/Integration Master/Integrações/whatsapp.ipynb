# %%
from Clients.callmebot_service import CallMeBot
from Clients.conversor_moeda import CoinConverterService

# %%
conversor_service = CoinConverterService()
conversion = conversor_service.converter('BTC', 'BRL')

# %%
wpp_service = CallMeBot()
wpp_service.send_message(
    message = f'A cotação do BitCoin está R$ {conversion}'
    )
# Out:
# '<p>Message to: +5581979007007<p>Text to send: A cotação do BitCoin está R$ 389794<p style="color:red"><b>APIKey is invalid.</b> Please create a new one or contact support if you lost it.'
