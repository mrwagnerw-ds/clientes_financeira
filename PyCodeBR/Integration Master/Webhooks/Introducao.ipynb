# %%
"""
Webhooks é um conceito, não é um app nem ferramenta.


Webhooks é uma tecnologia/conceito utilizado para permitir a comunicação entre duas aplicações e enviar notificações 
quase em tempo real.

Webhooks é um caminho unidirecional para comunicação de sistemas.

"""
