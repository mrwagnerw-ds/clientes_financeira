# %%
"""
A diferença entre listas e dicionários é que o dicionário tem uma chave agregada ao valor.

"""
# Out:
# '\nA diferença entre listas e dicionários é que o dicionário tem uma chave agregada ao valor.\n\n'

# %%
lista = ['Um', 'Dois', 'Três']
lista
# Out:
# ['Um', 'Dois', 'Três']

# %%
meu_dicio = {'nome': 'Felipe', 'idade':28, 'profissao':'Dev'}

# %%
meu_dicio['idade'] # Uma das formas de acesso ao dicionário
# Out:
# 28

# %%
meu_dicio.get('nome')
# Out:
# 'Felipe'

# %%
meu_dicio.pop('idade')
# Out:
# 28

# %%
meu_dicio
# Out:
# {'nome': 'Felipe', 'profissao': 'Dev'}

# %%
meu_dicio.keys()
# Out:
# dict_keys(['nome', 'profissao'])

# %%
meu_dicio.values()
# Out:
# dict_values(['Felipe', 'Dev'])

# %%
meu_dicio.clear()

# %%
meu_dicio
# Out:
# {}

# %%
pessoa = {
    'nome':'Felipe',
    'idade': 28,
    'profissao':'Dev',
    'interesses':['Python', 'Programação', 'Notebooks'],
    'pet': {
        'nome':'Loki',
        'idade':1,
        'peso':'2kg'
    }
}

# %%
pessoa.get('interesses')
# Out:
# ['Python', 'Programação', 'Notebooks']

# %%
pessoa.get('interesses')[0]
# Out:
# 'Python'

# %%
pessoa['interesses']
# Out:
# ['Python', 'Programação', 'Notebooks']

# %%
pessoa.get('pet')
# Out:
# {'nome': 'Loki', 'idade': 1, 'peso': '2kg'}

# %%
pessoa.get('pet').get('nome')
# Out:
# 'Loki'

# %%
pessoa['pet']['nome']
# Out:
# 'Loki'

# %%
pessoa
# Out:
# {'nome': 'Felipe',
#  'idade': 28,
#  'profissao': 'Dev',
#  'interesses': ['Python', 'Programação', 'Notebooks'],
#  'pet': {'nome': 'Loki', 'idade': 1, 'peso': '2kg'}}

# %%
pessoa['ano_nasciment'] = 1997 # Adicionando elementos ao dicionário.

# %%
pessoa
# Out:
# {'nome': 'Felipe',
#  'idade': 28,
#  'profissao': 'Dev',
#  'interesses': ['Python', 'Programação', 'Notebooks'],
#  'pet': {'nome': 'Loki', 'idade': 1, 'peso': '2kg'},
#  'ano_nasciment': 1997}

# %%
pessoa['cores_favoritas'] = ['Azul', 'Verde', 'Rosa']

# %%
pessoa
# Out:
# {'nome': 'Felipe',
#  'idade': 28,
#  'profissao': 'Dev',
#  'interesses': ['Python', 'Programação', 'Notebooks'],
#  'pet': {'nome': 'Loki', 'idade': 1, 'peso': '2kg'},
#  'ano_nasciment': 1997,
#  'cores_favoritas': ['Azul', 'Verde', 'Rosa']}

# %%
pessoa['mae'] = {
    'nome':'Maria',
    'idade':60
}

# %%
pessoa
# Out:
# {'nome': 'Felipe',
#  'idade': 28,
#  'profissao': 'Dev',
#  'interesses': ['Python', 'Programação', 'Notebooks'],
#  'pet': {'nome': 'Loki', 'idade': 1, 'peso': '2kg'},
#  'ano_nasciment': 1997,
#  'cores_favoritas': ['Azul', 'Verde', 'Rosa'],
#  'mae': {'nome': 'Maria', 'idade': 60}}
