# %%
carros = ['Marea','Fusca','Chevette']

# %%
carros.append('Corcel')

# %%
carros.insert(1, 'Scort') # Adicionando na posição que quiser.

# %%
del carros[1] # Passa o índice.

# %%
carros
# Out:
# ['Marea', 'Fusca', 'Chevette', 'Corcel']

# %%
carros.remove('Marea') # Passa o valor

# %%
carros.count('Fusca')
# Out:
# 1

# %%
numeros = [2,3,5,8,7,9,6,4,1]
numeros
# Out:
# [2, 3, 5, 8, 7, 9, 6, 4, 1]

# %%
numeros.sort()

# %%
numeros
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
